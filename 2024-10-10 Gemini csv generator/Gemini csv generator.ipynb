# %% [markdown]
# # Make a CSV of observations listed on Gemini web page

# %%
# from requests import request
import pandas as pd

gemini_url = "https://archive.gemini.edu/searchform/"

program_ids = ["GN-2024B-Q-305", "GS-2024B-Q-308"]

df = pd.read_html(gemini_url + program_ids[0], match="Proprietary", extract_links="all")[0]

# %%
df = df.rename(columns={name: f"col{i}" for i, name in enumerate(df.columns)})
df
# Out:
#                     col0                                         col1  \
# 0    (Proprietary, None)     (N20240814A0296b.fits, /fullheader/5876)
# 1    (Proprietary, None)     (N20240814A0296r.fits, /fullheader/5878)
# 2    (Proprietary, None)     (N20240814A0297b.fits, /fullheader/5886)
# 3    (Proprietary, None)     (N20240814A0297r.fits, /fullheader/5875)
# 4    (Proprietary, None)     (N20240814A0298r.fits, /fullheader/5869)
# ..                   ...                                          ...
# 131  (Proprietary, None)  (N20240927A0218b.fits, /fullheader/5700331)
# 132  (Proprietary, None)  (N20240927A0219b.fits, /fullheader/5700329)
# 133  (Proprietary, None)  (N20240927A0219r.fits, /fullheader/5700328)
# 134  (Proprietary, None)  (N20240927A0220b.fits, /fullheader/5700326)
# 135  (Proprietary, None)  (N20240927A0220r.fits, /fullheader/5700327)
#
#                                                   col2  \
# 0    ([A] GN-2024B-Q-305-0-0, /programinfo/GN-2024B...
# 1    ([A] GN-2024B-Q-305-0-0, /programinfo/GN-2024B...
# 2    ([A] GN-2024B-Q-305-0-0, /programinfo/GN-2024B...
# 3    ([A] GN-2024B-Q-305-0-0, /programinfo/GN-2024B...
# 4    ([A] GN-2024B-Q-305-0-0, /programinfo/GN-2024B...
# ..                                                 ...
# 131  ([A] GN-2024B-Q-305-0-0, /programinfo/GN-2024B...
# 132  ([A] GN-2024B-Q-305-0-0, /programinfo/GN-2024B...
# 133  ([A] GN-2024B-Q-305-0-0, /programinfo/GN-2024B...
# 134  ([A] GN-2024B-Q-305-0-0, /programinfo/GN-2024B...
# 135  ([A] GN-2024B-Q-305-0-0, /programinfo/GN-2024B...
#
#                                                   col3  \
# 0    (2024-08-14 06:22:02, /searchform/GN-2024B-Q-3...
# 1    (2024-08-14 06:22:02, /searchform/GN-2024B-Q-3...
# 2    (2024-08-14 06:23:04, /searchform/GN-2024B-Q-3...
# 3    (2024-08-14 06:23:04, /searchform/GN-2024B-Q-3...
# 4    (2024-08-14 06:24:07, /searchform/GN-2024B-Q-3...
# ..                                                 ...
# 131  (2024-09-27 12:18:01, /searchform/GN-2024B-Q-3...
# 132  (2024-09-27 12:19:02, /searchform/GN-2024B-Q-3...
# 133  (2024-09-27 12:19:02, /searchform/GN-2024B-Q-3...
# 134  (2024-09-27 12:24:21, /searchform/GN-2024B-Q-3...
# 135  (2024-09-27 12:24:21, /searchform/GN-2024B-Q-3...
#
#                                               col4  \
# 0    (ALOPEKE, /searchform/GN-2024B-Q-305/ALOPEKE)
# 1    (ALOPEKE, /searchform/GN-2024B-Q-305/ALOPEKE)
# 2    (ALOPEKE, /searchform/GN-2024B-Q-305/ALOPEKE)
# 3    (ALOPEKE, /searchform/GN-2024B-Q-305/ALOPEKE)
# 4    (ALOPEKE, /searchform/GN-2024B-Q-305/ALOPEKE)
# ..                                             ...
# 131  (ALOPEKE, /searchform/GN-2024B-Q-305/ALOPEKE)
# 132  (ALOPEKE, /searchform/GN-2024B-Q-305/ALOPEKE)
# 133  (ALOPEKE, /searchform/GN-2024B-Q-305/ALOPEKE)
# 134  (ALOPEKE, /searchform/GN-2024B-Q-305/ALOPEKE)
# 135  (ALOPEKE, /searchform/GN-2024B-Q-305/ALOPEKE)
#
#                                               col5  \
# 0    (science, /searchform/GN-2024B-Q-305/science)
# 1    (science, /searchform/GN-2024B-Q-305/science)
# 2    (science, /searchform/GN-2024B-Q-305/science)
# 3    (science, /searchform/GN-2024B-Q-305/science)
# 4    (science, /searchform/GN-2024B-Q-305/science)
# ..                                             ...
# 131  (science, /searchform/GN-2024B-Q-305/science)
# 132  (science, /searchform/GN-2024B-Q-305/science)
# 133  (science, /searchform/GN-2024B-Q-305/science)
# 134  (science, /searchform/GN-2024B-Q-305/science)
# 135  (science, /searchform/GN-2024B-Q-305/science)
#
#                                             col6                   col7  \
# 0    (OBJECT, /searchform/GN-2024B-Q-305/OBJECT)  (TIC 384410712, None)
# 1    (OBJECT, /searchform/GN-2024B-Q-305/OBJECT)  (TIC 384410712, None)
# 2    (OBJECT, /searchform/GN-2024B-Q-305/OBJECT)  (TIC 384410712, None)
# 3    (OBJECT, /searchform/GN-2024B-Q-305/OBJECT)  (TIC 384410712, None)
# 4    (OBJECT, /searchform/GN-2024B-Q-305/OBJECT)  (TIC 384410712, None)
# ..                                           ...                    ...
# 131  (OBJECT, /searchform/GN-2024B-Q-305/OBJECT)  (TIC 384735219, None)
# 132  (OBJECT, /searchform/GN-2024B-Q-305/OBJECT)  (TIC 384735219, None)
# 133  (OBJECT, /searchform/GN-2024B-Q-305/OBJECT)  (TIC 384735219, None)
# 134  (OBJECT, /searchform/GN-2024B-Q-305/OBJECT)         (HR 920, None)
# 135  (OBJECT, /searchform/GN-2024B-Q-305/OBJECT)         (HR 920, None)
#
#          col8          col9              col10
# 0    (, None)  (0.06, None)  (Undefined, None)
# 1    (, None)  (0.06, None)  (Undefined, None)
# 2    (, None)  (0.06, None)  (Undefined, None)
# 3    (, None)  (0.06, None)  (Undefined, None)
# 4    (, None)  (0.06, None)  (Undefined, None)
# ..        ...           ...                ...
# 131  (, None)  (0.06, None)  (Undefined, None)
# 132  (, None)  (0.06, None)  (Undefined, None)
# 133  (, None)  (0.06, None)  (Undefined, None)
# 134  (, None)  (0.06, None)  (Undefined, None)
# 135  (, None)  (0.06, None)  (Undefined, None)
#
# [136 rows x 11 columns]

# %%
t = Table.from_pandas(df)
t["col1"][0]
#this only gets the text of the fits file, not the links that get you the header info
# Out:
# ('N20240814A0296b.fits', '/fullheader/5876')
