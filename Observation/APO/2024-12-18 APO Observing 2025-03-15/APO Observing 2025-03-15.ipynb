# %%
from functools import partial
from sqlite3 import connect

import astroplan as ap
from astropy.coordinates import EarthLocation
from astropy.table import Table
from astropy.time import Time
import astropy.units as u
from icecream import ic, install
import numpy as np
import pandas as pd

import astropaul.targetlistcreator as tlc
import astropaul.lbt as lbt
import astropaul.html as html
import astropaul.phase as ph
import astropaul.priority as pr

install() # icecream will now work in imported packages

# %load_ext autoreload
# %autoreload 2

# from itables import init_notebook_mode

# init_notebook_mode(
#     all_interactive=True,
#     connected=True,
# )

# %%
conn = connect("../../django/TargetDB/db.sqlite3")

session = tlc.ObservingSession(ap.Observer.at_site("APO"))
session.add_full_day("2025-03-15")
session.add_full_day("2025-03-16")
session.add_half_day("2025-03-18", first_half=False)
session.add_full_day("2025-03-19")

phase_event_defs = [
    ph.PhaseEventDef("Not in Eclipse", partial(ph.calc_time_of_gress, ingress=False)),
    ph.PhaseEventDef("Eclipse", partial(ph.calc_time_of_gress, ingress=True)),
]

min_altitude = 35 * u.deg
max_magnitude = 12

name = "APO Observing List 2025-03-15 to -19"
creator = tlc.TargetListCreator(name=name, connection=conn)
creator.steps = [
    tlc.add_targets,
    partial(tlc.filter_targets, criteria=lambda df: (df["Target Type"].isin(["QuadEB", "SextEB"]))),
    tlc.add_tess,
    tlc.add_coords,
    partial(tlc.hide_cols, prefix="TESS "),
    partial(
        tlc.add_observability,
        observing_session=session,
        calc_moon_distance=True,
        observability_threshold=(min_altitude, 80 * u.deg),
    ),
    partial(tlc.filter_targets, criteria=lambda df: (df["Observable Any Night"])),
    partial(tlc.filter_targets, criteria=lambda df: (df["Vmag"] < max_magnitude)),
    tlc.add_ephemerides,
    partial(tlc.add_phase_events, observing_session=session, phase_event_defs=phase_event_defs),
    tlc.add_speckle,
    # partial(tlc.add_speckle_phase, phase_event_defs=phase_event_defs),
    partial(tlc.add_side_status, phase_event_defs=phase_event_defs),
]
tl = creator.calculate(verbose=False)

# html.render_observing_pages(tl, None, {}, "html")
print(tl.summarize())
# Out:
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460749.546375201, obsgeoloc=(620994.68724596, 5335156.29173947, 3433266.56774592) m, obsgeovel=(-389.03444343, 44.66993733, 0.95163754) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460750.546886344, obsgeoloc=(511920.18560585, 5346553.07666703, 3433533.79276051) m, obsgeovel=(-389.86552143, 36.71607824, 0.95399353) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460752.7993273837, obsgeoloc=(-5357380.07449845, 213888.62286414, 3448126.56067799) m, obsgeovel=(-15.58689976, -391.28141702, 0.05385454) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460753.548405687, obsgeoloc=(184096.34403994, 5367333.35471404, 3434339.46772331) m, obsgeovel=(-391.38097643, 12.81063982, 0.95879644) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 39
#      18 creator = tlc.TargetListCreator(name=name, connection=conn)
#      19 creator.steps = [
#      20     tlc.add_targets,
#      21     partial(tlc.filter_targets, criteria=lambda df: (df["Target Type"].isin(["QuadEB", "SextEB"]))),
#    (...)
#      37     partial(tlc.add_side_status, phase_event_defs=phase_event_defs),
#      38 ]
# ---> 39 tl = creator.calculate(verbose=False)
#      41 # html.render_observing_pages(tl, None, {}, "html")
#      42 print(tl.summarize())
#
# File ~\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:114, in TargetListCreator.calculate(self, initial_list, steps, verbose, **kwargs)
#     112     steps = self.steps
#     113 for step in steps:
# --> 114     intermediate_tl = step(intermediate_tl, **merged_kwargs)
#     115     if verbose:
#     116         print(f"{len(intermediate_tl.target_list):4d} targets, {step=}")
#
# File ~\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:621, in add_side_status(tl, phase_event_defs, side_state, **kwargs)
#     619     side_counts = side_observations.groupby("Target Name").size()
#     620     side_counts.name = "Num SIDE"
# --> 621     answer.target_list = answer.target_list.merge(side_counts, on="Target Name", how="left")
#     622     answer.target_list["Num SIDE"] = answer.target_list["Num SIDE"].fillna(0).astype(int)
#     623 return answer
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
#   10840         right_index=right_index,
#   10841         sort=sort,
#   10842         suffixes=suffixes,
#   10843         copy=copy,
#   10844         indicator=indicator,
#   10845         validate=validate,
#   10846     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:807, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     803 self._validate_tolerance(self.left_join_keys)
#     805 # validate the merge keys dtypes. We may need to coerce
#     806 # to avoid incompatible dtypes
# --> 807 self._maybe_coerce_merge_keys()
#     809 # If argument passed to validate,
#     810 # check if columns specified as unique
#     811 # are in fact unique.
#     812 if validate is not None:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:1508, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1502     # unless we are merging non-string-like with string-like
#    1503     elif (
#    1504         inferred_left in string_types and inferred_right not in string_types
#    1505     ) or (
#    1506         inferred_right in string_types and inferred_left not in string_types
#    1507     ):
# -> 1508         raise ValueError(msg)
#    1510 # datetimelikes must match exactly
#    1511 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on object and int64 columns for key 'Target Name'. If you wish to proceed you should use pd.concat

# %%
altitude_categories = [
    ((-90, min_altitude.value), 0),
    ((min_altitude.value, 90), 1),
]

pl = pr.PriorityList(tl, session, interval=30 * u.min)
pr.calculate_altitude_priority(pl, altitude_categories=altitude_categories)
pr.prioritize_phase_sequence(pl, ["Eclipse"], "Eclipse", True, True, True)
pr.prioritize_side_observation(pl, side_state="Eclipse")
pr.calculate_overall_priority(pl)
pr.aggregate_target_priorities(pl, skip_column_threshold=0.1)
pl.categorize_priorities(bins=[0.00, 0.20, 0.40, 0.6, 1.00], labels=["", "*", "* *", "* * *"])

html.render_observing_pages(tl, pl, {}, "../../Observing Files/APO Observing 2025-03-15 to -19")
# pl.categorical_priorities[0]

# %%
q2_session = tlc.ObservingSession(ap.Observer.at_site("APO"))
q2_session.add_day_range("2025-05-07", "2025-06-11")

creator = tlc.TargetListCreator(name="APO 2025-Q2 Proposal", connection=conn)

creator.steps = [
    tlc.add_targets,
    partial(tlc.filter_targets, criteria=lambda df: (df["Target Type"].isin(["QuadEB", "SextEB"]))),
    partial(
        tlc.filter_targets,
        inverse=True,
        criteria=lambda df: (
            df["Target Name"].isin([pl.overall_category_members["* * *"], pl.overall_category_members["* *"]])
        ),
    ),
    tlc.add_tess,
    tlc.add_coords,
    partial(tlc.hide_cols, prefix="TESS "),
    partial(
        tlc.add_observability,
        observing_session=q2_session,
        calc_moon_distance=True,
        observability_threshold=(min_altitude, 80 * u.deg),
    ),
    partial(tlc.filter_targets, criteria=lambda df: (df["Observable Any Night"])),
    partial(tlc.filter_targets, criteria=lambda df: (df["Vmag"] < max_magnitude)),
    tlc.add_ephemerides,
    partial(tlc.add_phase_events, observing_session=q2_session, phase_event_defs=phase_event_defs),
    tlc.add_speckle,
    partial(tlc.add_speckle_phase, phase_event_defs=phase_event_defs),
]

q2_tl = creator.calculate()
print(q2_tl.summarize())
# Out:
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460802.5727789286, obsgeoloc=(-4402146.58107771, 3063469.32233906, 3445737.59503973) m, obsgeovel=(-223.38166529, -321.62770952, 0.56237224) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460803.5732806055, obsgeoloc=(-4463605.9333481, 2973027.24969252, 3445892.8347298) m, obsgeovel=(-216.78655215, -326.10942963, 0.5462968) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460804.573780753, obsgeoloc=(-4523183.27461147, 2881395.84557423, 3446043.73585992) m, obsgeovel=(-210.10473557, -330.45390981, 0.5299692) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460805.5742832073, obsgeoloc=(-4580923.85613628, 2788503.88794331, 3446190.51639392) m, obsgeovel=(-203.3310199, -334.66445829, 0.51338524) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460806.5747842346, obsgeoloc=(-4636736.21719605, 2694496.70309689, 3446333.00091842) m, obsgeovel=(-196.47599737, -338.73441267, 0.49658154) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2
m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:419: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = dist
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[column_name] = segment_observability
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:405: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[hours_observable_column] = segment_hours_observable
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:408: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[max_alt_column] = segment_max_alts
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460828.5848695063, obsgeoloc=(-5342797.46436333, 448631.28755559, 3448201.21319736) m, obsgeovel=(-32.70583986, -390.22350231, 0.0944823) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:419: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = dist
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[column_name] = segment_observability
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:405: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[hours_observable_column] = segment_hours_observable
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:408: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[max_alt_column] = segment_max_alts
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460829.585253628, obsgeoloc=(-5350566.8254, 343547.12572947, 3448225.10915526) m, obsgeovel=(-25.04297417, -390.79010534, 0.0756072) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:419: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = dist
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[column_name] = segment_observability
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:405: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[hours_observable_column] = segment_hours_observable
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:408: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[max_alt_column] = segment_max_alts
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460830.5856278925, obsgeoloc=(-5356258.20528265, 238663.63330969, 3448243.6243042) m, obsgeovel=(-17.39476327, -391.20516584, 0.05672532) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:419: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = dist
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[column_name] = segment_observability
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:405: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[hours_observable_column] = segment_hours_observable
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:408: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[max_alt_column] = segment_max_alts
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460831.585991944, obsgeoloc=(-5359888.53645149, 134033.97738797, 3448256.9732835) m, obsgeovel=(-9.76508619, -391.46992802, 0.03784462) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:419: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = dist
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[column_name] = segment_observability
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:405: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[hours_observable_column] = segment_hours_observable
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:408: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[max_alt_column] = segment_max_alts
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460832.5863454393, obsgeoloc=(-5361476.44777036, 29710.25117443, 3448265.35885157) m, obsgeovel=(-2.15773994, -391.58575919, 0.01897749) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:419: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = dist
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[column_name] = segment_observability
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:405: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[hours_observable_column] = segment_hours_observable
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:408: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[max_alt_column] = segment_max_alts
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460833.586688041, obsgeoloc=(-5361042.20631324, -74256.41601946, 3448268.96150588) m, obsgeovel=(5.42355177, -391.5541447, 0.00013993) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:419: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = dist
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[column_name] = segment_observability
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:405: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[hours_observable_column] = segment_hours_observable
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:408: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[max_alt_column] = segment_max_alts
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460834.587019423, obsgeoloc=(-5358607.66661189, -177816.01106835, 3448267.93123922) m, obsgeovel=(12.97514894, -391.3766836, -0.0186494) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:419: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = dist
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[column_name] = segment_observability
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:405: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[hours_observable_column] = segment_hours_observable
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:408: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[max_alt_column] = segment_max_alts
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460835.5873403586, obsgeoloc=(-5354194.27937108, -280956.55540137, 3448262.37644466) m, obsgeovel=(20.49618665, -391.05494297, -0.03737664) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:419: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = dist
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[column_name] = segment_observability
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:405: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[hours_observable_column] = segment_hours_observable
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:408: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[max_alt_column] = segment_max_alts
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460836.587652055, obsgeoloc=(-5347821.11598774, -383681.40760874, 3448252.35052886) m, obsgeovel=(27.986919, -390.59031338, -0.05602978) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:419: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = dist
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[column_name] = segment_observability
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:405: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[hours_observable_column] = segment_hours_observable
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:408: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[max_alt_column] = segment_max_alts
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2460837.5879514534, obsgeoloc=(-5339517.86281173, -485850.74476109, 3448237.87326314) m, obsgeovel=(35.43715864, -389.98495628, -0.07457139) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:419: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = dist
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:425: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[any_night_column] = overall_any_night
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:427: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[every_night_column] = overall_every_night
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:430: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[max_alt_column] = overall_max_alts
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:433: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[min_hours_observable_column] = overall_min_hours_observable
# C:\Users\User\Dropbox\Astro\astropaul\astropaul\targetlistcreator.py:437: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   answer.target_list[moon_dist_column] = overall_min_moon_dist
# APO 2025-Q2 Proposal
# 24 targets:
#       24 QuadEB
# Column Count (primary, secondary):
#     Target: (1, 2)
#     Coordinates: (6, 3)
#     Observable: (5, 144)
#     Count: (1, 0)
# Associated tables:
#       36 rows,  2 columns: Lunar Phases
#       80 rows,  7 columns: Ephem
#     4041 rows, 10 columns: Phase Events
#       54 rows,  6 columns: Speckle
#      181 rows,  7 columns: Speckle Phases

# %%
q2_pl = pr.PriorityList(q2_tl, q2_session, interval=30 * u.min)
pr.calculate_altitude_priority(q2_pl, altitude_categories=altitude_categories)
pr.prioritize_phase_sequence(q2_pl, ["Eclipse"], "Eclipse", True, True, True)
pr.prioritize_side_observation(q2_pl, side_phases=["Eclipse"])
pr.calculate_overall_priority(q2_pl)
pr.aggregate_target_priorities(q2_pl, skip_column_threshold=0.0)
q2_pl.categorize_priorities(bins=[0.00, 0.20, 0.40, 0.6, 1.00], labels=["", "*", "* *", "* * *"])

html.render_observing_pages(q2_tl, q2_pl, {}, "../../Observing Files/APO 2025-Q2 Proposal")
# pl.categorical_priorities[0]
